# %%
import pandas as pd
#series with list
data = [100,200,300,123,45,1231,7564, 855]
#series
series = pd.Series(data)

print(series <= 70)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
#series with dictionary
calories = {"Marky" :100, "Jane" : 21 , "nicky" : 54 , "mario" : 32}
series = pd.Series(calories)
series.loc["jane"] =  10
print(series)
# Out:
# Marky    100
# Jane      21
# nicky     54
# mario     32
# jane      10
# dtype: int64

# %%
data = {"name" : ["sponge bob", "Tom cruise", "John wick"], 
       "age" : [10, 23, 43 ],
        "email" : ["sponge@gmail.com", "tom@gmail.com", "john@gmail.com" ]
       }
df = pd.DataFrame(data, index=["Employee 1", "Employee 2", "Employee 3"])

df["job"] = ["Act as cock", "Act as CIA", "Act as killer"]

new_dt = pd.DataFrame([{"name" : "Sandy", "age" : 16, "email" : "sandy@gmail.com", "job" : "astronut"}, 
                      {"name" : "airmjay", "age" : 10, "email" : "airmjay@gmail.com", "job" : "programmer"}], 
                      index=["Employee 4", "Employee 5"])
df = pd.concat([df, new_dt])
print(df.loc["Employee 1"])
# Out:
# name           sponge bob
# age                    10
# email    sponge@gmail.com
# job           Act as cock
# Name: Employee 1, dtype: object

# %%
df = pd.read_csv("pre.csv")
print(df.to_string())
# Out:
#      AdminID       AdminName     UID     Category             Position                 Name          Tenure
# 0   OBJ-1999  Obasanjo Admin  PRE-01    Executive            President    Olusegun Obasanjo     1999 - 2007
# 1   OBJ-1999  Obasanjo Admin  VPR-01    Executive       Vice President       Atiku Abubakar     1999 - 2007
# 2   OBJ-1999  Obasanjo Admin  SEN-01  Legislative     Senate President     Anyim Pius Anyim     2000 - 2003
# 3   OBJ-1999  Obasanjo Admin  SEN-02  Legislative     Senate President      Adolphus Wabara     2003 - 2005
# 4   OBJ-1999  Obasanjo Admin  SEN-03  Legislative     Senate President          Ken Nnamani     2005 - 2007
# 5   OBJ-1999  Obasanjo Admin  MIN-01    Executive  Minister of Finance  Ngozi Okonjo-Iweala     2003 - 2006
# 6   OBJ-1999  Obasanjo Admin  MIN-02    Executive      Minister of FCT       Nasir El-Rufai     2003 - 2007
# 7   OBJ-1999  Obasanjo Admin  WAG-01     Economic         Minimum Wage               ₦5,500     2000 - 2011
# 8   YAR-2007  Yar'Adua Admin  PRE-02    Executive            President  Umaru Musa Yar'Adua     2007 - 2010
# 9   YAR-2007  Yar'Adua Admin  VPR-02    Executive       Vice President    Goodluck Jonathan     2007 - 2010
# 10  YAR-2007  Yar'Adua Admin  SEN-04  Legislative     Senate President           David Mark     2007 - 2015
# 11  GEJ-2010  Jonathan Admin  PRE-03    Executive            President    Goodluck Jonathan     2010 - 2015
# 12  GEJ-2010  Jonathan Admin  VPR-03    Executive       Vice President         Namadi Sambo     2010 - 2015
# 13  GEJ-2010  Jonathan Admin  MIN-03    Executive  Minister of Finance  Ngozi Okonjo-Iweala     2011 - 2015
# 14  GEJ-2010  Jonathan Admin  WAG-02     Economic         Minimum Wage              ₦18,000     2011 - 2019
# 15  PMB-2015    Buhari Admin  PRE-04    Executive            President     Muhammadu Buhari     2015 - 2023
# 16  PMB-2015    Buhari Admin  VPR-04    Executive       Vice President        Yemi Osinbajo     2015 - 2023
# 17  PMB-2015    Buhari Admin  SEN-05  Legislative     Senate President        Bukola Saraki     2015 - 2019
# 18  PMB-2015    Buhari Admin  SEN-06  Legislative     Senate President          Ahmed Lawan     2019 - 2023
# 19  PMB-2015    Buhari Admin  MIN-04    Executive  Minister of Finance         Zainab Ahmed     2018 - 2023
# 20  PMB-2015    Buhari Admin  WAG-03     Economic         Minimum Wage              ₦30,000     2019 - 2024
# 21  BAT-2023    Tinubu Admin  PRE-05    Executive            President    Bola Ahmed Tinubu  2023 - Present
# 22  BAT-2023    Tinubu Admin  VPR-05    Executive       Vice President      Kashim Shettima  2023 - Present
# 23  BAT-2023    Tinubu Admin  SEN-07  Legislative     Senate President     Godswill Akpabio  2023 - Present
# 24  BAT-2023    Tinubu Admin  MIN-05    Executive  Minister of Finance            Wale Edun  2023 - Present
# 25  BAT-2023    Tinubu Admin  WAG-04     Economic         Minimum Wage              ₦70,000  2024 - Present
